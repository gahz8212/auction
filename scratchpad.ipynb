# %% [markdown]
# <a href="https://colab.research.google.com/github/gahz8212/auction/blob/master/scratchpad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('google')
# Out:
# google

# %%
print('jhoi')
# Out:
# jhoi

# %%
print('dream')
# Out:
# dream

# %%
#쉬프트 엔터:현재 셀 실행하고 다음셀 생성함
